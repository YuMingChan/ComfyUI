# %% [markdown]
# <a href="https://colab.research.google.com/github/YuMingChan/ComfyUI/blob/main/ComfyUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 強制安裝並升級環境
# !pip install pyngrok --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --quiet

# 2. 拉取 ComfyUI
# %cd /content
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI
# !pip install -r requirements.txt --quiet

# 3. 安裝 Manager
# !git clone https://github.com/ltdrdata/ComfyUI-Manager custom_nodes/ComfyUI-Manager

# 4. 準備 ngrok 連線 (請將你的 Token 填入)
from pyngrok import ngrok, conf
# 填入你的 Token
ngrok.set_auth_token("38QXDws33LUKGhPGwc34PPNcQSL_4tmxQR3w6DhBHaYtqmQe")

# 建立隧道
tunnel = ngrok.connect(8188)
print(f"✅ 隧道已建立，請點擊連結: {tunnel.public_url}")

# 5. 啟動 ComfyUI
# 這一行會卡住 Cell，這是正常的，因為 Server 正在跑
# !python main.py --listen 0.0.0.0 --port 8188
# Out:
# /content
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 40341, done.
# remote: Counting objects: 100% (360/360), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 40341 (delta 291), reused 198 (delta 196), pack-reused 39981 (from 3)
# Receiving objects: 100% (40341/40341), 82.38 MiB | 18.64 MiB/s, done.
# Resolving deltas: 100% (27203/27203), done.
# /content/ComfyUI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.7/22.7 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 101.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 100.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.2/340.2 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 MB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 MB 10.8 MB/s eta 0:00:00
# ...

# %%
# 先做安裝，唔好 import 任何嘢
# !pip install pyngrok --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --quiet
print("✅ 安裝完成，請執行下一個 Cell")
# Out:
# ✅ 安裝完成，請執行下一個 Cell

# %%
import os
import subprocess
import time
from google.colab import drive
from pyngrok import ngrok, conf
from google.colab.output import eval_js

# 1. 掛載 Google Drive
drive.mount('/content/drive')

# 2. 設定 Ngrok (最重要)
# 確保你嘅 Token 喺度
ngrok.set_auth_token("38QXDws33LUKGhPGwc34PPNcQSL_4tmxQR3w6DhBHaYtqmQe")
ngrok.kill() # 強制清除舊隧道，避免 port 被佔用

# 3. 建立並切換到 ComfyUI 目錄
# %cd /content
if not os.path.exists("ComfyUI"):
    # !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI

# 4. 對接模型庫 (Drive)
drive_models = "/content/drive/MyDrive/ComfyUI/models"
if not os.path.exists(drive_models):
    os.makedirs(drive_models, exist_ok=True)
# !rm -rf models
# !ln -s {drive_models} models

# 5. 安裝組件
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --quiet
# !pip install -r requirements.txt --quiet
# !pip install pyngrok --quiet
if not os.path.exists("custom_nodes/ComfyUI-Manager"):
    # !git clone https://github.com/ltdrdata/ComfyUI-Manager custom_nodes/ComfyUI-Manager

# 6. 啟動 Ngrok 隧道
public_url = ngrok.connect(8188)
print(f"✅ 隧道已建立，請點擊連結進入 ComfyUI: {public_url.public_url}")

# 7. 設定 CUDA 並啟動主程式
os.environ['LD_LIBRARY_PATH'] = '/usr/local/nvidia/lib64:/usr/local/cuda/lib64'
# !python main.py --listen 0.0.0.0 --port 8188
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# /content/ComfyUI
# ✅ 隧道已建立，請點擊連結進入 ComfyUI: https://threadlike-paleontographical-marietta.ngrok-free.dev
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-06-04 17:52:03.614
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ...
